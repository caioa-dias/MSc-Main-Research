# %%
import tensorflow
import keras
import numpy as np
import sklearn as skl
import pandas as pd
import joblib
from matplotlib import pyplot as plt

# %%
lf_model_path = 'utils/MLP-ANN.keras'
lf_model = keras.models.load_model(lf_model_path)

# %%
def build_pinn_loss(panel_dx: np.ndarray, panel_dy: np.ndarray, lambda_physical: float,
    y_scaler: skl.preprocessing.StandardScaler):
    """
    
    """

    # --- Converting to tensorflow constants ---
    panel_dx = tensorflow.constant(panel_dx, dtype=tensorflow.float32)
    panel_dy = tensorflow.constant(panel_dy, dtype=tensorflow.float32)

    y_mean = y_scaler.mean_.astype(np.float32)
    y_scale = y_scaler.scale_.astype(np.float32)

    Cl_mean = tensorflow.constant(y_mean[0:1].reshape(1, 1), dtype=tensorflow.float32)
    Cl_scale = tensorflow.constant(y_scale[0:1].reshape(1, 1), dtype=tensorflow.float32)

    Cp_mean = tensorflow.constant(y_mean[1:].reshape(1, -1), dtype=tensorflow.float32)
    Cp_scale = tensorflow.constant(y_scale[1:].reshape(1, -1), dtype=tensorflow.float32)

    def pinn_loss(y_true: np.ndarray, y_pred: np.ndarray):
        """
        
        """

        # --- Casting to float32 ---
        y_true = tensorflow.cast(y_true, dtype=tensorflow.float32)
        y_pred = tensorflow.cast(y_pred, dtype=tensorflow.float32)

        # --- Defines the true supervised values ---
        AoA_deg = y_true[:, -1:]

        # --- Defines the predicted supervised values ---
        Cl_pred = y_pred[:, 0:1]
        Cp_pred = y_pred[:, 1:]

        # --- Defines the supervised loss as a global MSE ---
        supervised_true = y_true[:, :-1]
        supervised_pred = y_pred
        data_loss = tensorflow.reduce_mean(tensorflow.square(supervised_true - supervised_pred))

        # --- Reescales the predicted supervised values ---
        Cl_pred_raw = Cl_pred * Cl_scale + Cl_mean
        Cp_pred_raw = Cp_pred * Cp_scale + Cp_mean

        # --- Computes the average Cp for each panel ---
        panel_Cp = 0.5 * (Cp_pred_raw[:, :-1] + Cp_pred_raw[:, 1:])

        # --- Integrates to find normal (Cn) and axial (Ca) force coefficients ---
        Cn = tensorflow.reduce_sum(panel_Cp * panel_dx, axis=1, keepdims=True)
        Ca = -tensorflow.reduce_sum(panel_Cp * panel_dy, axis=1, keepdims=True)

        # --- Defines the angle of attack in radians ---
        AoA_rad = AoA_deg * (np.pi / 180.0)

        # --- Projects Cn and Ca into the lift coefficient (Cl) using the angle of attack ---
        Cl_from_Cp_raw = Cn * tensorflow.cos(AoA_rad) - Ca * tensorflow.sin(AoA_rad)

        # --- Defines the physical loss ---
        physical_loss = tensorflow.reduce_mean(tensorflow.square(Cl_pred_raw - Cl_from_Cp_raw))

        # --- Defines the training loss ---
        loss = data_loss + lambda_physical * physical_loss

        return loss
    
    return pinn_loss

def pinn_supervised_mse(y_true: np.ndarray, y_pred: np.ndarray):
    """
    
    """

    # --- Casting float 32 ---
    y_true = tensorflow.cast(y_true, dtype=tensorflow.float32)
    y_pred = tensorflow.cast(y_pred, dtype=tensorflow.float32)

    # --- Defines the true supervised values, excluding the angle of attack ---
    supervised_true = y_true[:, :-1]

    # --- Calculates the supervised mean squared error ---
    supervised_mse = tensorflow.reduce_mean(tensorflow.square(supervised_true - y_pred))

    return supervised_mse

def pinn_supervised_mae(y_true: np.ndarray, y_pred: np.ndarray):
    """
    
    """

    # --- Casting to float32 ---
    y_true = tensorflow.cast(y_true, dtype=tensorflow.float32)
    y_pred = tensorflow.cast(y_pred, dtype=tensorflow.float32)

    # --- Defines the true supervised values, excluding the angle of attack ---
    supervised_true = y_true[:, :-1]

    # --- Calculates the mean absolute error ---
    supervised_mae = tensorflow.reduce_mean(tensorflow.abs(supervised_true - y_pred))

    return supervised_mae

def build_physical_metric(panel_dx: np.ndarray, panel_dy: np.ndarray, y_scaler: skl.preprocessing.StandardScaler):
    """
    
    """

    # --- Converting to tensorflow constants ---
    panel_dx = tensorflow.constant(panel_dx, dtype=tensorflow.float32)
    panel_dy = tensorflow.constant(panel_dy, dtype=tensorflow.float32)

    y_mean = y_scaler.mean_.astype(np.float32)
    y_scale = y_scaler.scale_.astype(np.float32)

    Cl_mean = tensorflow.constant(y_mean[0:1].reshape(1, 1), dtype=tensorflow.float32)
    Cl_scale = tensorflow.constant(y_scale[0:1].reshape(1, 1), dtype=tensorflow.float32)

    Cp_mean = tensorflow.constant(y_mean[1:].reshape(1, -1), dtype=tensorflow.float32)
    Cp_scale = tensorflow.constant(y_scale[1:].reshape(1, -1), dtype=tensorflow.float32)

    def physical_mse(y_true: np.ndarray, y_pred: np.ndarray):
        """
        
        """

        # --- Casting to float32 ---
        y_true = tensorflow.cast(y_true, dtype=tensorflow.float32)
        y_pred = tensorflow.cast(y_pred, dtype=tensorflow.float32)

        # --- Defines the true and predicted values ---
        Cl_pred = y_pred[:, 0:1]
        Cp_pred = y_pred[:, 1:]
        AoA_deg = y_true[:, -1:]

        # --- Reescales the predicted values ---
        Cl_pred_raw = Cl_pred * Cl_scale + Cl_mean
        Cp_pred_raw = Cp_pred * Cp_scale + Cp_mean

        # --- Computes the average Cp for each panel ---
        panel_Cp = 0.5 * (Cp_pred_raw[:, :-1] + Cp_pred_raw[:, 1:])

        # --- Integrates to find normal (Cn) and axial (Ca) force coefficients ---
        Cn = tensorflow.reduce_sum(panel_Cp * panel_dx, axis=1, keepdims=True)
        Ca = -tensorflow.reduce_sum(panel_Cp * panel_dy, axis=1, keepdims=True)

        # --- Defines the angle of attack in radians ---
        AoA_rad = AoA_deg * (np.pi / 180.0)

        # --- Projects Cn and Ca into the lift coefficient (Cl) using the angle of attack ---
        Cl_from_Cp_raw = Cn * tensorflow.cos(AoA_rad) - Ca * tensorflow.sin(AoA_rad)

        # --- Defines the physical loss ---
        return tensorflow.reduce_mean(tensorflow.square(Cl_pred_raw - Cl_from_Cp_raw))

    return physical_mse

def load_transfer_model(lf_model_path: str, n_frozen_layers: int, learning_rate, panel_dx, panel_dy, y_scaler):
    model = keras.models.load_model(lf_model_path)

    for layer in model.layers[:n_frozen_layers]:
        layer.trainable = False

    for layer in model.layers[n_frozen_layers:]:
        layer.trainable = True

    loss = build_pinn_loss(panel_dx, panel_dy, lambda_physical=0.2, y_scaler=y_scaler)
    physical_metric = build_physical_metric(panel_dx, panel_dy, y_scaler)

    pinn_supervised_mae.__name__ = 'supervised_mae'
    pinn_supervised_mse.__name__ = 'supervised_mse'
    physical_metric.__name__ = 'physical_mse'

    model.compile(optimizer=keras.optimizers.Nadam(learning_rate=learning_rate), loss=loss, 
        metrics=[pinn_supervised_mse, pinn_supervised_mae, physical_metric])
    
    return model

def print_trainable_layers(model):
    for i, layer in enumerate(model.layers):
        status = 'trainable' if layer.trainable else 'frozen'
        print(f'{i:02d} | {layer.name} | {status}')

# %%
def match_effective_angle_cases(data, AoA_effective_data):

    hf_cases = data[['Re', 'AoA', 'y']].to_numpy(dtype=np.float64)
    lf_cases = AoA_effective_data[['Re', 'AoA', 'y']].to_numpy(dtype=np.float64)

    std_values = AoA_effective_data[['Re', 'AoA', 'y']].std().to_numpy(dtype=np.float64)

    AoA_effective_values = AoA_effective_data['AoA_Effective'].to_numpy(dtype=np.float64)

    matched_AoA_effective = []

    for case in hf_cases:
        distance = np.sqrt(
            ((lf_cases[:, 0] - case[0]) / std_values[0]) ** 2 +
            ((lf_cases[:, 1] - case[1]) / std_values[1]) ** 2 +
            ((lf_cases[:, 2] - case[2]) / std_values[2]) ** 2)
        
        closest_idx = np.argmin(distance)
        matched_AoA_effective.append(AoA_effective_values[closest_idx])

    matched_AoA_effective = np.array(matched_AoA_effective, dtype=np.float32)

    return matched_AoA_effective

def load_and_split_data(filepath, AoA_effective):

    data = (pd.read_csv(filepath, sep=';')).copy()
    data['AoA_Effective'] = match_effective_angle_cases(data=data, AoA_effective_data=AoA_effective)
    
    wing_sections = 1
    idx = np.arange(len(data))
    data['flow_case'] = idx // wing_sections
    unique_cases = data['flow_case'].unique()
    train_cases, test_cases = skl.model_selection.train_test_split(unique_cases, test_size=0.2,
        random_state=42, shuffle=True)
    train_cases, val_cases = skl.model_selection.train_test_split(train_cases, test_size=0.2,
        random_state=42, shuffle=True)

    # --- Separate the datasets ---
    data_train = data[data['flow_case'].isin(train_cases)]
    data_val = data[data['flow_case'].isin(val_cases)].drop(columns=['flow_case'])
    data_test = data[data['flow_case'].isin(test_cases)]

    return data_train, data_val, data_test

def preprocess_data(data_train, data_val, data_test, X_scaler):

    X_cols = ['Re', 'AoA', 'y']
    y_cols = ['cl'] + [col for col in data_train.columns[4:] if col != 'AoA_Effective' and col != 'flow_case']

    X_train_raw = data_train[X_cols].to_numpy()
    X_val_raw = data_val[X_cols].to_numpy()
    X_test_raw = data_test[X_cols].to_numpy()

    AoA_train_raw = data_train[['AoA_Effective']].to_numpy()
    AoA_val_raw = data_val[['AoA_Effective']].to_numpy()
    AoA_test_raw = data_test[['AoA_Effective']].to_numpy()

    y_train_raw = data_train[y_cols].to_numpy()
    y_val_raw = data_val[y_cols].to_numpy()
    y_test_raw = data_test[y_cols].to_numpy()

    X_train = X_scaler.transform(X_train_raw)
    X_val = X_scaler.transform(X_val_raw)
    X_test = X_scaler.transform(X_test_raw)

    y_scaler_hf = skl.preprocessing.StandardScaler()
    y_train = y_scaler_hf.fit_transform(y_train_raw)
    y_val = y_scaler_hf.transform(y_val_raw)
    y_test = y_scaler_hf.transform(y_test_raw)

    y_train = np.hstack((y_train, AoA_train_raw))
    y_val = np.hstack((y_val, AoA_val_raw))

    return X_train, y_train, X_val, y_val, X_test, y_test, y_scaler_hf

airfoil_data = pd.read_csv('utils/NACA23015.csv', sep=',', names=['x', 'y'])
AoA_effective_data = pd.read_csv('utils/LowFidelity-AoAEffectiveData.csv', sep=';')
panel_dx = np.diff(airfoil_data['x'].values).astype(np.float32)
panel_dy = np.diff(airfoil_data['y'].values).astype(np.float32)
X_scaler = joblib.load('utils/mlp_ann_X_scaler.pkl')
y_scaler_lf = joblib.load('utils/mlp_ann_y_scaler.pkl')

data_train, data_val, data_test = load_and_split_data('utils/HighFidelity-AviationInterpolated-PressureDistributionData.csv', AoA_effective_data) 

X_train_hf, y_train_hf, X_val_hf, y_val_hf, X_test_hf, y_test_hf, y_scaler_hf = preprocess_data(data_train, data_val, data_test, X_scaler)

transfer_model = load_transfer_model(lf_model_path, n_frozen_layers=3, learning_rate=1e-4, panel_dx=panel_dx, panel_dy=panel_dy, y_scaler=y_scaler_hf)
print_trainable_layers(transfer_model)
# Out:
# 00 | Input_Layer | frozen
# 01 | Hidden_Layer_1 | frozen
# 02 | Hidden_Layer_2 | frozen
# 03 | Hidden_Layer_3 | trainable
# 04 | Hidden_Layer_4 | trainable
# 05 | Hidden_Layer_5 | trainable
# 06 | Output_Layer | trainable

# %%
callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, min_delta=1e-6, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=8, min_lr=1e-7, verbose=1),
    keras.callbacks.ModelCheckpoint(filepath='tl-frozen-layers.keras',
        monitor='val_loss', save_best_only=True, verbose=1)]

loss = build_pinn_loss(panel_dx, panel_dy, lambda_physical=0.2, y_scaler=y_scaler_hf)

history = transfer_model.fit(X_train_hf, y_train_hf, validation_data=(X_val_hf, y_val_hf), epochs=500, batch_size=32,
    callbacks=callbacks, verbose=1)
# Out:
# Epoch 1/500
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0133 - physical_mse: 1.0685e-05 - supervised_mae: 0.0646 - supervised_mse: 0.0133
# Epoch 1: val_loss improved from None to 0.02012, saving model to tl-frozen-layers.keras
#
# Epoch 1: finished saving model to tl-frozen-layers.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0137 - physical_mse: 1.2922e-05 - supervised_mae: 0.0643 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4269e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 2/500
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0242 - physical_mse: 1.7294e-05 - supervised_mae: 0.0720 - supervised_mse: 0.0242
# Epoch 2: val_loss improved from 0.02012 to 0.02012, saving model to tl-frozen-layers.keras
#
# Epoch 2: finished saving model to tl-frozen-layers.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0137 - physical_mse: 1.2922e-05 - supervised_mae: 0.0644 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4253e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 3/500
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - physical_mse: 1.4736e-05 - supervised_mae: 0.0655 - supervised_mse: 0.0143
# Epoch 3: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.2913e-05 - supervised_mae: 0.0644 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4232e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 4/500
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0125 - physical_mse: 1.3081e-05 - supervised_mae: 0.0634 - supervised_mse: 0.0125
# Epoch 4: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.2935e-05 - supervised_mae: 0.0643 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4256e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 5/500
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0134 - physical_mse: 1.2578e-05 - supervised_mae: 0.0650 - supervised_mse: 0.0134
# Epoch 5: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.2882e-05 - supervised_mae: 0.0642 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4259e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 6/500
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0133 - physical_mse: 1.4982e-05 - supervised_mae: 0.0625 - supervised_mse: 0.0133
# Epoch 6: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.3045e-05 - supervised_mae: 0.0645 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4264e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 7/500
# 16/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0139 - physical_mse: 1.3043e-05 - supervised_mae: 0.0633 - supervised_mse: 0.0139
# Epoch 7: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.2991e-05 - supervised_mae: 0.0646 - supervised_mse: 0.0138 - val_loss: 0.0201 - val_physical_mse: 7.4249e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 8/500
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0151 - physical_mse: 1.2733e-05 - supervised_mae: 0.0662 - supervised_mse: 0.0151
# Epoch 8: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.2961e-05 - supervised_mae: 0.0643 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4251e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 9/500
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - physical_mse: 1.0347e-05 - supervised_mae: 0.0652 - supervised_mse: 0.0143
# Epoch 9: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.2896e-05 - supervised_mae: 0.0643 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4256e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 10/500
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0103 - physical_mse: 8.1797e-06 - supervised_mae: 0.0610 - supervised_mse: 0.0103
# Epoch 10: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.3079e-05 - supervised_mae: 0.0645 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4272e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 11/500
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0131 - physical_mse: 1.2354e-05 - supervised_mae: 0.0633 - supervised_mse: 0.0131
# Epoch 11: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.3052e-05 - supervised_mae: 0.0644 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4237e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 12/500
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0151 - physical_mse: 1.2932e-05 - supervised_mae: 0.0674 - supervised_mse: 0.0151
# Epoch 12: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.3107e-05 - supervised_mae: 0.0645 - supervised_mse: 0.0138 - val_loss: 0.0201 - val_physical_mse: 7.4254e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 13/500
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0137 - physical_mse: 1.4158e-05 - supervised_mae: 0.0645 - supervised_mse: 0.0137
# Epoch 13: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.2864e-05 - supervised_mae: 0.0643 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4233e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 14/500
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0095 - physical_mse: 1.0353e-05 - supervised_mae: 0.0570 - supervised_mse: 0.0095
# Epoch 14: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.2859e-05 - supervised_mae: 0.0643 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4242e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 15/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0130 - physical_mse: 1.1289e-05 - supervised_mae: 0.0642 - supervised_mse: 0.0130
# Epoch 15: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.3079e-05 - supervised_mae: 0.0644 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4238e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 16/500
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0124 - physical_mse: 1.3354e-05 - supervised_mae: 0.0631 - supervised_mse: 0.0124
# Epoch 16: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.2873e-05 - supervised_mae: 0.0644 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4265e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 17/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0154 - physical_mse: 1.3029e-05 - supervised_mae: 0.0658 - supervised_mse: 0.0154
# Epoch 17: val_loss improved from 0.02012 to 0.02012, saving model to tl-frozen-layers.keras
#
# Epoch 17: finished saving model to tl-frozen-layers.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0137 - physical_mse: 1.2884e-05 - supervised_mae: 0.0642 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4254e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 18/500
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0144 - physical_mse: 1.1387e-05 - supervised_mae: 0.0649 - supervised_mse: 0.0144
# Epoch 18: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.2952e-05 - supervised_mae: 0.0643 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4228e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 19/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0133 - physical_mse: 1.3174e-05 - supervised_mae: 0.0650 - supervised_mse: 0.0133
# Epoch 19: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.3078e-05 - supervised_mae: 0.0644 - supervised_mse: 0.0138 - val_loss: 0.0201 - val_physical_mse: 7.4230e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 20/500
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0128 - physical_mse: 1.0802e-05 - supervised_mae: 0.0633 - supervised_mse: 0.0128
# Epoch 20: val_loss improved from 0.02012 to 0.02012, saving model to tl-frozen-layers.keras
#
# Epoch 20: finished saving model to tl-frozen-layers.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0137 - physical_mse: 1.3031e-05 - supervised_mae: 0.0648 - supervised_mse: 0.0141 - val_loss: 0.0201 - val_physical_mse: 7.4245e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 21/500
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0136 - physical_mse: 1.2593e-05 - supervised_mae: 0.0635 - supervised_mse: 0.0136
# Epoch 21: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.2945e-05 - supervised_mae: 0.0643 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4240e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 22/500
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0180 - physical_mse: 2.9713e-05 - supervised_mae: 0.0745 - supervised_mse: 0.0180
# Epoch 22: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.2991e-05 - supervised_mae: 0.0644 - supervised_mse: 0.0138 - val_loss: 0.0201 - val_physical_mse: 7.4249e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 23/500
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0104 - physical_mse: 1.5347e-05 - supervised_mae: 0.0560 - supervised_mse: 0.0104
# Epoch 23: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.2843e-05 - supervised_mae: 0.0644 - supervised_mse: 0.0138 - val_loss: 0.0201 - val_physical_mse: 7.4272e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 24/500
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0083 - physical_mse: 4.6519e-06 - supervised_mae: 0.0564 - supervised_mse: 0.0083
# Epoch 24: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.3121e-05 - supervised_mae: 0.0644 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4300e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 25/500
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0131 - physical_mse: 1.3616e-05 - supervised_mae: 0.0635 - supervised_mse: 0.0131
# Epoch 25: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.2997e-05 - supervised_mae: 0.0643 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4287e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 26/500
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0149 - physical_mse: 1.4096e-05 - supervised_mae: 0.0654 - supervised_mse: 0.0149
# Epoch 26: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.2834e-05 - supervised_mae: 0.0641 - supervised_mse: 0.0136 - val_loss: 0.0201 - val_physical_mse: 7.4297e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 27/500
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0144 - physical_mse: 2.5070e-05 - supervised_mae: 0.0667 - supervised_mse: 0.0144
# Epoch 27: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.3064e-05 - supervised_mae: 0.0645 - supervised_mse: 0.0138 - val_loss: 0.0201 - val_physical_mse: 7.4281e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 28/500
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0102 - physical_mse: 7.4268e-06 - supervised_mae: 0.0600 - supervised_mse: 0.0102
# Epoch 28: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.3158e-05 - supervised_mae: 0.0646 - supervised_mse: 0.0140 - val_loss: 0.0201 - val_physical_mse: 7.4284e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 29/500
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0131 - physical_mse: 1.0158e-05 - supervised_mae: 0.0633 - supervised_mse: 0.0131
# Epoch 29: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.3122e-05 - supervised_mae: 0.0643 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4277e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 30/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0140 - physical_mse: 1.2473e-05 - supervised_mae: 0.0652 - supervised_mse: 0.0140
# Epoch 30: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.2907e-05 - supervised_mae: 0.0642 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4281e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 31/500
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0159 - physical_mse: 1.2095e-05 - supervised_mae: 0.0670 - supervised_mse: 0.0159
# Epoch 31: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.2943e-05 - supervised_mae: 0.0644 - supervised_mse: 0.0138 - val_loss: 0.0201 - val_physical_mse: 7.4252e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 32/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0135 - physical_mse: 1.3975e-05 - supervised_mae: 0.0644 - supervised_mse: 0.0135
# Epoch 32: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.3180e-05 - supervised_mae: 0.0645 - supervised_mse: 0.0138 - val_loss: 0.0201 - val_physical_mse: 7.4304e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 33/500
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0140 - physical_mse: 7.2577e-06 - supervised_mae: 0.0657 - supervised_mse: 0.0140
# Epoch 33: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.3233e-05 - supervised_mae: 0.0643 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4287e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 34/500
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0139 - physical_mse: 1.2658e-05 - supervised_mae: 0.0626 - supervised_mse: 0.0139
# Epoch 34: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137 - physical_mse: 1.3063e-05 - supervised_mae: 0.0643 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4267e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 35/500
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0129 - physical_mse: 1.2054e-05 - supervised_mae: 0.0642 - supervised_mse: 0.0129
# Epoch 35: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.2859e-05 - supervised_mae: 0.0642 - supervised_mse: 0.0136 - val_loss: 0.0201 - val_physical_mse: 7.4283e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 36/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0138 - physical_mse: 1.1494e-05 - supervised_mae: 0.0636 - supervised_mse: 0.0138
# Epoch 36: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.3106e-05 - supervised_mae: 0.0644 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4292e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 37/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0139 - physical_mse: 1.2037e-05 - supervised_mae: 0.0654 - supervised_mse: 0.0139
# Epoch 37: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.2826e-05 - supervised_mae: 0.0642 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4261e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 38/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143 - physical_mse: 1.4819e-05 - supervised_mae: 0.0649 - supervised_mse: 0.0143
# Epoch 38: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.2933e-05 - supervised_mae: 0.0644 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4281e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 39/500
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0131 - physical_mse: 1.2459e-05 - supervised_mae: 0.0640 - supervised_mse: 0.0130
# Epoch 39: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.2875e-05 - supervised_mae: 0.0643 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4298e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07
# Epoch 40/500
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0102 - physical_mse: 1.6421e-05 - supervised_mae: 0.0584 - supervised_mse: 0.0102
# Epoch 40: val_loss did not improve from 0.02012
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137 - physical_mse: 1.2858e-05 - supervised_mae: 0.0644 - supervised_mse: 0.0137 - val_loss: 0.0201 - val_physical_mse: 7.4260e-06 - val_supervised_mae: 0.0722 - val_supervised_mse: 0.0182 - learning_rate: 1.0000e-07

# %%
def inverse_transform_y(y_scaled, y_scaler):
    return y_scaler.inverse_transform(y_scaled)

def predict_real_scale(model, X_scaled, y_scaler):
    y_pred_scaled = model.predict(X_scaled, verbose=0)
    y_pred_real = inverse_transform_y(y_pred_scaled, y_scaler)
    return y_pred_real

y_hf_real = inverse_transform_y(y_test_hf, y_scaler_hf)

y_lf_pred_real = predict_real_scale(model=lf_model, X_scaled=X_test_hf, y_scaler=y_scaler_lf)

y_mf_pred_real = predict_real_scale(model=transfer_model, X_scaled=X_test_hf, y_scaler=y_scaler_hf)

def plot_cp_comparison_lf_hf_mf(x_cp, y_lf, y_hf, y_mf, sample_idx, case_info=None, invert_yaxis=True, figsize=(7, 4)):
    plt.figure(figsize=figsize)

    plt.plot(x_cp, y_lf[sample_idx][1:], linestyle='-', linewidth=0.8, label='LF prediction', color='b')
    plt.plot(x_cp, y_hf[sample_idx][1:], linestyle='-', linewidth=0.8, label='HF reference', color='k')
    plt.plot(x_cp, y_mf[sample_idx][1:], linestyle='--', linewidth=0.8, label='MF prediction', color='r')

    plt.xlabel('x/c')
    plt.ylabel('Cp')

    if invert_yaxis:
        plt.gca().invert_yaxis()

    title = f'Cp comparison - Sample {sample_idx}'

    if case_info is not None:
        info_text = ', '.join([f'{k}={v}' for k, v in case_info.items()])
        title += f'\n{info_text}'

    plt.title(title)
    plt.grid(True, alpha=0.25)
    plt.legend()
    plt.tight_layout()
    plt.show()
    return

sample_idx = 40

with open('utils/LowFidelity-PressureDistributionData.csv', 'r', encoding='utf-8') as f:
    header = f.readline().strip()

headers = header.split(';')

x_cp = np.array([float(col) for col in headers[4:]])

plot_cp_comparison_lf_hf_mf(
    x_cp=x_cp,
    y_lf=y_lf_pred_real,
    y_hf=y_hf_real,
    y_mf=y_mf_pred_real,
    sample_idx=sample_idx)

# %%
def compute_sample_rmse(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred) ** 2, axis=1))

rmse_lf = compute_sample_rmse(y_hf_real, y_lf_pred_real)
rmse_mf = compute_sample_rmse(y_hf_real, y_mf_pred_real)

improvement = rmse_lf - rmse_mf

comparison_df = pd.DataFrame({
    'sample_idx': np.arange(len(rmse_lf)),
    'rmse_lf_vs_hf': rmse_lf,
    'rmse_mf_vs_hf': rmse_mf,
    'improvement_lf_minus_mf': improvement,
    'relative_improvement_percent': 100 * improvement / rmse_lf
})

comparison_df = comparison_df.sort_values(
    by='improvement_lf_minus_mf',
    ascending=False
)

plt.figure(figsize=(6, 4))

plt.hist(rmse_lf, bins=30, alpha=0.6, label='LF vs HF')
plt.hist(rmse_mf, bins=30, alpha=0.6, label='MF vs HF')

plt.xlabel('RMSE in Cp')
plt.ylabel('Number of samples')
plt.title('Distribution of Cp RMSE')
plt.grid(True, alpha=0.25)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 5))

plt.scatter(rmse_lf, rmse_mf, s=20, alpha=0.7)

min_value = min(rmse_lf.min(), rmse_mf.min())
max_value = max(rmse_lf.max(), rmse_mf.max())

plt.plot(
    [min_value, max_value],
    [min_value, max_value],
    linestyle='--',
    linewidth=1.2,
    label='LF = MF'
)

plt.xlabel('RMSE LF vs HF')
plt.ylabel('RMSE MF vs HF')
plt.title('Sample-wise error comparison')
plt.grid(True, alpha=0.25)
plt.legend()
plt.tight_layout()
plt.show()

# %%
def compute_global_metrics(y_true, y_pred, label='Model'):
    """
    Compute global regression metrics in physical scale.
    """

    error = y_true - y_pred

    mse = np.mean(error ** 2)
    rmse = np.sqrt(mse)
    mae = np.mean(np.abs(error))

    ss_res = np.sum(error ** 2)
    ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
    r2 = 1 - ss_res / ss_tot

    return {
        'model': label,
        'MSE': mse,
        'RMSE': rmse,
        'MAE': mae,
        'R2': r2
    }


metrics_df = pd.DataFrame([
    compute_global_metrics(y_hf_real, y_lf_pred_real, label='LF'),
    compute_global_metrics(y_hf_real, y_mf_pred_real, label='MF')
])

print(metrics_df)
# Out:
#   model       MSE      RMSE       MAE        R2
# 0    LF  0.108852  0.329928  0.194224  0.744297
# 1    MF  0.000579  0.024066  0.013795  0.998639
